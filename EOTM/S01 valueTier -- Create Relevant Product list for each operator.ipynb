# %%
from pyspark.sql import functions as f
from pyspark.sql import types as t
import dateutil.parser 
from pyspark.sql import Window
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Read relevant tables

# %%
countryCode = 'za'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
universe  =  spark.table('dev_derived_ouniverse.output_total_universe_'+countryCode).drop("CityGoogle46","ohubId","integer") \
                   .withColumn('d_buyer',f.when(f.col("operatorOhubId").isNotNull(),f.lit(1)).otherwise(f.lit(0)))

sale      =  spark.table("dev_sources_ohub.cleaned_operator_sales") \
                  .where(f.lower(f.col('countryCode')) == countryCode) \
                  .where(f.col('cuEanCode').isNotNull()) \
                  .where(f.col('transactionDate').isNotNull()) \
                  .where(f.col('amount') > 0)

menu      =  spark.table("dev_derived_omenu.output_business_product_mapping_long").where(f.lower(f.col('countryCode')) == countryCode)
productDetails = spark.table('data_sifu.sifu_product_details').where(f.lower(f.col('countryCode')) ==countryCode)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sale.select('operatorOhubId').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: 33787</div>

# %% [markdown]
# #### Create table with relevant products per operator based on the menu data

# %%
menuCuEanCode  = menu.alias('m').join(productDetails.alias('p'),menu.productCode == productDetails.productCode,how = 'left_outer').select('m.*','p.cuEanCodes').where(f.col('cuEanCodes').isNotNull()).withColumnRenamed('cuEanCodes','cuEanCode').select('id','cuEanCode', 'productName').distinct()

relevantProductsMenu = universe.join(menuCuEanCode, on = universe.placeIdGoogle == menuCuEanCode.id, how = 'inner').select('operatorid','cuEanCode', 'productName').distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-653118697554818&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>menuCuEanCode  <span class="ansi-blue-fg">=</span> menu<span class="ansi-blue-fg">.</span>alias<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;m&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>join<span class="ansi-blue-fg">(</span>productDetails<span class="ansi-blue-fg">.</span>alias<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;p&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span>menu<span class="ansi-blue-fg">.</span>productCode <span class="ansi-blue-fg">==</span> productDetails<span class="ansi-blue-fg">.</span>productCode<span class="ansi-blue-fg">,</span>how <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;left_outer&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;m.*&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;p.cuEanCodes&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>where<span class="ansi-blue-fg">(</span>f<span class="ansi-blue-fg">.</span>col<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;cuEanCodes&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>isNotNull<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>withColumnRenamed<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;cuEanCodes&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;cuEanCode&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;id&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;cuEanCode&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;productName&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>distinct<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> relevantProductsMenu <span class="ansi-blue-fg">=</span> universe<span class="ansi-blue-fg">.</span>join<span class="ansi-blue-fg">(</span>menuCuEanCode<span class="ansi-blue-fg">,</span> on <span class="ansi-blue-fg">=</span> universe<span class="ansi-blue-fg">.</span>placeIdGoogle <span class="ansi-blue-fg">==</span> menuCuEanCode<span class="ansi-blue-fg">.</span>id<span class="ansi-blue-fg">,</span> how <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;inner&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;operatorid&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;cuEanCode&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;productName&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>distinct<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">__getattr__</span><span class="ansi-blue-fg">(self, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1417</span>         <span class="ansi-green-fg">if</span> name <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">in</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   1418</span>             raise AttributeError(
# <span class="ansi-green-fg">-&gt; 1419</span><span class="ansi-red-fg">                 &#34;&#39;%s&#39; object has no attribute &#39;%s&#39;&#34; % (self.__class__.__name__, name))
# </span><span class="ansi-green-intense-fg ansi-bold">   1420</span>         jc <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>apply<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1421</span>         <span class="ansi-green-fg">return</span> Column<span class="ansi-blue-fg">(</span>jc<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;DataFrame&#39; object has no attribute &#39;productCode&#39;</div>

# %%
display(relevantProductsMenu)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-653118697554819&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>display<span class="ansi-blue-fg">(</span>relevantProductsMenu<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;relevantProductsMenu&#39; is not defined</div>

# %% [markdown]
# ##### Validate uniqueness menu table

# %%
print(
      'Menu table row count: ', menuCuEanCode.distinct().count(), '\n',
      'Menu table id count: ', menuCuEanCode.select('id', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count(), '\n',
      'relevant products menu table  row count: ', relevantProductsMenu.count(), '\n',
      'relevant products menu table id count: ', relevantProductsMenu.select('operatorid', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count()
     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Menu table row count:  0
#  Menu table id count:  0
#  relevant products menu table  row count:  0
#  relevant products menu table id count:  0
# </div>

# %%
w1 = Window.partitionBy(f.concat(f.col('id'),f.lit('/'),f.col('cuEanCode'))).orderBy(f.desc('productName'))
menuCuEanCode = menuCuEanCode.select('id','cuEanCode',f.first('productName').over(w1).alias('productName')).distinct()

w2 = Window.partitionBy(f.concat(f.col('operatorid'),f.lit('/'),f.col('cuEanCode'))).orderBy(f.desc('productName'))
relevantProductsMenu = relevantProductsMenu.select('operatorid','cuEanCode',f.first('productName').over(w2).alias('productName')).distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
w = Window.partitionBy(f.concat(f.col('id'),f.lit('/'),f.col('cuEanCode')))
display(menuCuEanCode.select('*', f.count('productName').over(w).alias('dupeCount'))\
    .where('dupeCount > 1')\
    .drop('dupeCount'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>cuEanCode</th><th>productName</th></tr></thead><tbody></tbody></table></div>

# %%
print(
      'Menu table row count: ', menuCuEanCode.distinct().count(), '\n',
      'Menu table id count: ', menuCuEanCode.select('id', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count(), '\n',
      'relevant products menu table  row count: ', relevantProductsMenu.count(), '\n',
      'relevant products menu table id count: ', relevantProductsMenu.select('operatorid', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count()
     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Menu table row count:  0
#  Menu table id count:  0
#  relevant products menu table  row count:  0
#  relevant products menu table id count:  0
# </div>

# %% [markdown]
# #### Create table with relevant products per operator based on the sales data

# %%
# sale = sale.withColumn('year',f.substring(f.col('transactiondate'),1,4).cast('int')).where(f.col('year') >= 2019)
sale = sale.where(f.col('amount') > 0)
display(sale)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>countryCode</th><th>orderType</th><th>transactionDate</th><th>ohubUpdated</th><th>operatorOhubId</th><th>operatorConcatID</th><th>sourceProductCode</th><th>productID</th><th>language</th><th>productCode</th><th>cuEanCode</th><th>duEanCode</th><th>productCodeLocal</th><th>productName</th><th>productType</th><th>quantityOfUnits</th><th>amount</th><th>pricePerUnit</th><th>cuListingPriceInCents</th><th>duListingPriceInCents</th><th>packagingCode</th><th>packagingName</th><th>brandCode</th><th>brandName</th><th>subBrandCode</th><th>subBrandName</th><th>categoryCode</th><th>categoryName</th><th>subcategoryCode</th><th>subcategoryName</th></tr></thead><tbody><tr><td>ZA</td><td>Appshop</td><td>2019-07-18T10:12:51.000+0000</td><td>2019-07-30T11:09:06.801+0000</td><td>6b0215b0-8799-3d7c-8c09-3eb0bdd6ffc0</td><td>ZA~EMAKINA~6c491a9e-22c4-4aa2-a6c3-ad3ee53f7722</td><td>2 - CU EAN</td><td>d0766d0a60bc232e4c177b4d5df781aae45a631acbd94e83f967b54cfaf1e03f</td><td>en</td><td>1-EN-12603</td><td>6001087305006</td><td>16001087304112</td><td>11007</td><td>Knorr Professional Tomato  Pronto</td><td>PRODUCT</td><td>3</td><td>366.0</td><td>122.0</td><td>13000</td><td>78000</td><td>1045</td><td>6 x 2kg</td><td>148</td><td>Knorr</td><td>1823</td><td>Knorr Professional</td><td>4147</td><td>Stocks</td><td>10985</td><td>Knorr Professional</td></tr><tr><td>ZA</td><td>Appshop</td><td>2019-08-27T07:20:21.000+0000</td><td>2019-08-28T04:25:47.263+0000</td><td>7e72bba4-47a7-33dc-a552-572a3cdf3506</td><td>ZA~EMAKINA~2bd88545-a8c4-4c24-86a8-98eeded3cb40</td><td>2 - CU EAN</td><td>64c9036972346383cb70284806e414c4d06b7bd83c578874374c1b971dc8aafc</td><td>en</td><td>1-EN-74780</td><td>6001087314848</td><td>16001087313039</td><td>12499</td><td>Robertsons Veggie Seasoning</td><td>PRODUCT</td><td>1</td><td>120.0</td><td>120.0</td><td>12500</td><td>75000</td><td>1020</td><td>6 x 1kg</td><td>171</td><td>Robertsons</td><td>409</td><td>not defined</td><td>701</td><td>Seasonings</td><td>10983</td><td>Robertsons Seasoning Blends</td></tr><tr><td>ZA</td><td>Appshop</td><td>2019-08-27T07:25:40.000+0000</td><td>2019-08-28T04:25:47.263+0000</td><td>7e72bba4-47a7-33dc-a552-572a3cdf3506</td><td>ZA~EMAKINA~2bd88545-a8c4-4c24-86a8-98eeded3cb40</td><td>1 - DU EAN</td><td>06900f335bdc6b57ff640c4b65f7443e5161d8bdca3a8bc7a68040e388de8d6c</td><td>en</td><td>1-EN-194331</td><td>6001087362405</td><td>6001087362405</td><td>21165447</td><td>Knorr Professional Spicy Chicken Breading</td><td>PRODUCT</td><td>1</td><td>203.0</td><td>203.0</td><td>21600</td><td>21600</td><td>12626</td><td>1 X 5kg</td><td>148</td><td>Knorr</td><td>419</td><td>Savoury</td><td>701</td><td>Seasonings</td><td>10982</td><td>Knorr Seasonings</td></tr><tr><td>ZA</td><td>Appshop</td><td>2019-08-27T07:25:40.000+0000</td><td>2019-08-28T04:25:47.263+0000</td><td>7e72bba4-47a7-33dc-a552-572a3cdf3506</td><td>ZA~EMAKINA~2bd88545-a8c4-4c24-86a8-98eeded3cb40</td><td>2 - CU EAN</td><td>4f9154f743b065e42b08ce617c66e0b1325109c18bdcaeff948d550f8d7b45de</td><td>en</td><td>1-EN-53149</td><td>6001087313766</td><td>16001087312230</td><td>12388</td><td>Knorr Professional Peri-Peri Marinade</td><td>PRODUCT</td><td>1</td><td>76.0</td><td>76.0</td><td>8100</td><td>48600</td><td>1016</td><td>6 x 1 kg</td><td>148</td><td>Knorr</td><td>373</td><td>not defined</td><td>4148</td><td>Marinades</td><td>10997</td><td>Dry Marinades</td></tr><tr><td>ZA</td><td>Appshop</td><td>2019-10-29T15:51:35.000+0000</td><td>2019-12-16T02:21:50.642+0000</td><td>1610e1db-7695-3c7e-888e-f68c2fe6c0e4</td><td>ZA~EMAKINA~8b971272-a17f-412a-9ecf-15b68845ddf6</td><td>2 - CU EAN</td><td>31521123885a306715e10463aa52c2566a857e97d666818298662f0e6c46fe02</td><td>en</td><td>1-EN-264095</td><td>6001087375801</td><td>26001087375805</td><td>67398417</td><td>Robertsons Barbecue Spice Pack</td><td>PRODUCT</td><td>1</td><td>318.84</td><td>318.84</td><td>6400</td><td>38 ...

# %% [markdown]
# ##### Get Relevant products for operator from the sales table

# %%
universeRelevantProductsSSD = universe.alias('u').join(sale.alias('s'), on= universe.operatorOhubID == sale.operatorOhubId, how ='inner').select('u.operatorid','s.cuEanCode','s.productName').distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(universeRelevantProductsSSD)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>operatorid</th><th>cuEanCode</th><th>productName</th></tr></thead><tbody><tr><td>2162839119 /  / 051c053f-dfde-314c-86d4-06f7d774457d</td><td>6001087305815</td><td>Robertsons Medium Rajah</td></tr><tr><td> /  / 44ee70fd-4671-324c-8a4d-a29d091e1b75</td><td>6001087009430</td><td>Knorr Professional Cheese Sauce Powder, 800 g</td></tr><tr><td> /  / 5971d338-11ee-3de4-8915-79f0fb9c4206</td><td>6001087309479</td><td>Robertsons Parsley </td></tr><tr><td> /  / ee681a76-42ae-3870-af9b-a179fe350e57</td><td>6001087009447</td><td>Knorr Professional Roast Onion Gravy Powder, 800 g </td></tr><tr><td> /  / f4b3c093-0276-4572-b257-4ad2bafe9b94</td><td>6001087009454</td><td>Knorr Professional Mushroom Sauce Powder, 800 g</td></tr><tr><td> /  / 01cd9a07-94e2-3844-ab01-5b657e82aab3</td><td>6001087309455</td><td>Robertsons Italian Herb Seasoning</td></tr><tr><td> /  / 0c03b346-aa59-3de7-b881-479baee10a63</td><td>6001087001090</td><td>Hellmann's Tangy Mayonnaise 2.5kg</td></tr><tr><td> /  / 4d80170f-648b-3e6d-b934-a17a82134b80</td><td>6001087309530</td><td>Robertsons Paprika </td></tr><tr><td> /  / 2ae66328-f979-3a4a-aa14-5604982b82ba</td><td>6001087354950</td><td>Knorr Professional Beef Stock Granules</td></tr><tr><td> /  / f6c5c126-537e-395b-80fe-83d4af5e4274</td><td>6001087354967</td><td>Knorr Professional Vegetable Stock Granules</td></tr><tr><td> /  / b05042b4-c61e-3cc7-a1fb-96ed177951bb</td><td>6001087307970</td><td>Robertsons Savoury Rice</td></tr><tr><td> /  / 5d328c1e-b660-3422-8c09-b914493b66fa</td><td>6001087307420</td><td>CARTE D'OR 2-In-1 Chocolate Sauce and Milkshake Syrup</td></tr><tr><td> /  / 5bec0269-cf53-3a82-a186-d87ee8048d6c</td><td>6001087009447</td><td>Knorr Professional Roast Onion Gravy Powder, 800 g </td></tr><tr><td> /  / 6c5308a8-7130-4816-9710-c1e519a3158f</td><td>6001087309530</td><td>Robertsons Paprika </td></tr><tr><td> /  / c03bfade-f242-3b9c-970c-69918f74c1cc</td><td>6001087354950</td><td>Knorr Professional Beef Stock Granules</td></tr><tr><td> /  / 1c61a20a-4295-3d73-a57f-0f9933488f25</td><td>6001087307086</td><td>Robertsons Barbecue Spice </td></tr><tr><td> /  / 8c075140-ec95-3c77-8872-8dd9c8e18bdf</td><td>6001087007184</td><td>Fine Foods Tomato Sauce</td></tr><tr><td> /  / c8c8a6bd-43fa-3421-b970-84f0e7cbbb9d</td><td>6001087307413</td><td>CARTE D'OR Chocolate Mousse</td></tr><tr><td> /  / a95ed5a5-a348-3116-b034-9f3eab11843a</td><td>6001087001076</td><td>Hellmann's Tangy Mayonnaise 20kg</td></tr><tr><td> /  / 44234353-38c2-3a96-be5d-15060b303988</td><td>6001087355001</td><td>Fine Foods Fruit Chutney </td></tr><tr><td> /  / aae58f1f-61f3-3c9e-9a73-3180c253b46c</td><td>6001087375757</td><td>Robertsons Steak & Chops Spice Pack</td></tr><tr><td> /  / ae46d43a-fa64-3c23-9972-067ad96a1c1d</td><td>6001087314848</td><td>Robertsons Veggie Seasoning</td></tr><tr><td> /  / a433b6fd-74aa-3a45-b689-e532b5ae593c</td><td>6001087366397</td><td>Hellmann's Original Mayonnaise 3.57kg</td></tr><tr><td> /  / f79cabac-f80d-4797-8a3c-84cfa09d1bbc</td><td>6001087001076</td><td>Hellmann's Tangy Mayonnaise 20kg</td></tr><tr><td> /  / 1a92438b-3543-4585-800b-dd19a19a140e</td><td>16001087306161</td><td>CARTE D'OR Custard Powder</td></tr><tr><td> /  / f2f4039f-1f09-3b4b-bee9-caf6b288de1b</td><td>6001087307550</td><td>CARTE D'OR Chocolate Flavoured Milkshake Syrup</td></tr><tr><td> /  / 2279e1c4-0bc7-3fbb-8451-7929caa294a3</td><td>16001087306109</td><td>CARTE D'OR Assorted Jelly</td></tr><tr><td> /  / 732ca64a-9a95-3ffb-9e65-04aa811c4860</td><td>6001087309431</td><td>Robertsons Cinnamon</td></tr><tr><td> /  / 28c6d671-c3f5-3961-9c0f-78a54b00eb65</td><td>6001087307918</td><td>Robertsons Cajun Spice</td></tr><tr><td> /  / f3d1337a-b6b4-32a1-876a-42b2794b2aac</td><td>6001087305815</td><td>Robertsons Medium Rajah</td></tr><tr><td> /  / 350e3636-417d-309b-84ed-e5cd416255ba</td><td>6001087307611</td><td>Robertsons Steak & Chops S ...

# %%
print(
      'relevant products SSD table row count: ', universeRelevantProductsSSD.count(), '\n',
      'relevant products SSD table id count: ', universeRelevantProductsSSD.select('operatorid', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count()
     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">relevant products SSD table row count:  199144
#  relevant products SSD table id count:  199140
# </div>

# %%
w3 = Window.partitionBy(f.concat(f.col('operatorid'),f.lit('/'),f.col('cuEanCode'))).orderBy(f.desc('productName'))
universeRelevantProductsSSD = universeRelevantProductsSSD.\
                                select('operatorid','cuEanCode',f.first('productName').over(w3).alias('productName')).distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(
      'relevant products SSD table row count: ', universeRelevantProductsSSD.count(), '\n',
      'relevant products SSD table id count: ', universeRelevantProductsSSD.select('operatorid', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count()
     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">relevant products SSD table row count:  199140
#  relevant products SSD table id count:  199140
# </div>

# %%
universeRelevantProductsSSD.select('operatorid').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 9856</div>

# %% [markdown]
# #### Combine both relevant product tables using an union

# %%
relevantProductsMenu = relevantProductsMenu.withColumn('rationale', f.lit('Menu Data'))
universeRelevantProductsSSD = universeRelevantProductsSSD.withColumn('rationale', f.lit('Sales Data'))

relevantProductsMenu = relevantProductsMenu.join(universeRelevantProductsSSD, on = ['operatorid'], how = 'left_anti')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(relevantProductsMenu)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>operatorid</th><th>cuEanCode</th><th>productName</th><th>rationale</th></tr></thead><tbody></tbody></table></div>

# %%
relevantProducts = relevantProductsMenu.union(universeRelevantProductsSSD)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.window import Window

w = Window.partitionBy(f.when(f.col('operatorid').isNotNull(),f.col('operatorid')).otherwise(''),\
                              f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')\
                      ).orderBy(f.when(f.col('rationale').isNotNull(),f.col('rationale')).otherwise('').asc()\
                               )
                                                               
relevantProducts = relevantProducts.withColumn("rank", f.dense_rank().over(w)).where(f.col('rank')==1).drop('rank')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
relevantProducts = relevantProducts.select('operatorid', 'rationale', 'cuEanCode', f.lower(f.col('productName')).alias('productName')).\
withColumn('productName',f.regexp_replace(f.col('productName'), '  ', ' ')).\
groupBy('operatorid','cuEanCode', 'rationale').\
agg(f.max(f.col('productName')).alias('productName'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(relevantProducts.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;operatorid&#39;, &#39;cuEanCode&#39;, &#39;rationale&#39;, &#39;productName&#39;]
# </div>

# %%
# 233.563

print(
      'relevant products table row count: ', relevantProducts.count(), '\n',
      'relevant products table id count: ', relevantProducts.select('operatorid', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count()
     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">relevant products table row count:  199140
#  relevant products table id count:  199140
# </div>

# %% [markdown]
# #### Show duplicate records

# %%
duplicateRows = relevantProducts.groupBy('operatorid', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('').alias('cuEanCode')).agg(f.count(f.lit(1)).alias('cntRecords')).where(f.col('cntRecords') > 1)

relevantProducts.join(duplicateRows, on = ['operatorid','cuEanCode'], how = 'inner').orderBy('operatorid','cuEanCode').show(truncate = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+---------+---------+-----------+----------+
# operatorid|cuEanCode|rationale|productName|cntRecords|
# +----------+---------+---------+-----------+----------+
# +----------+---------+---------+-----------+----------+
#
# </div>

# %% [markdown]
# #### Create Universe table joined with the relevant products

# %%
universeRelevantProducts = universe.join(relevantProducts, on = ['operatorid'], how = 'left_outer').distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(relevantProducts.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;operatorid&#39;, &#39;cuEanCode&#39;, &#39;rationale&#39;, &#39;productName&#39;]
# </div>

# %%
print(
      'universe with relevant products table row count: ', universeRelevantProducts.count(), '\n',
      'universe with relevant products table id count: ', universeRelevantProducts.select('operatorid', f.when(f.col('cuEanCode').isNotNull(),f.col('cuEanCode')).otherwise('')).distinct().count()
     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">universe with relevant products table row count:  254582
#  universe with relevant products table id count:  254582
# </div>

# %%
display(universeRelevantProducts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>operatorId</th><th>osmId</th><th>placeIdGoogle</th><th>operatorOhubID</th><th>name</th><th>address</th><th>postalCode</th><th>city</th><th>latitude</th><th>longitude</th><th>businessType</th><th>website</th><th>phone</th><th>nameGoogle</th><th>addressGoogle</th><th>postalCodeGoogle</th><th>cityGoogle16</th><th>latitudeGoogle</th><th>longitudeGoogle</th><th>businessTypeGoogle</th><th>websiteGoogle</th><th>type</th><th>uid</th><th>user_sid</th><th>nameOSM</th><th>addressOSM</th><th>postalCodeOSM</th><th>cityOSM</th><th>latitudeOSM</th><th>longitudeOSM</th><th>businessTypeOSM</th><th>websiteOSM</th><th>cuisineTypeOSM</th><th>phoneOSM</th><th>nameOHUB</th><th>addressOhub</th><th>zipcodeOHUB</th><th>cityOHUB</th><th>operatorConcatID</th><th>channelOHUB</th><th>source</th><th>globalChannel</th><th>cuisineType</th><th>chain</th><th>globalListChannels</th><th>addressCombined</th><th>d_buyer</th><th>cuEanCode</th><th>rationale</th><th>productName</th></tr></thead><tbody><tr><td> /  / 004f037a-3fd4-3b92-bd6e-57b19d398531</td><td>null</td><td>null</td><td>004f037a-3fd4-3b92-bd6e-57b19d398531</td><td>Kaygeeâ€™s kitchen</td><td>null</td><td>2940</td><td>null</td><td>null</td><td>null</td><td>catering</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Kaygeeâ€™s kitchen</td><td>null</td><td>2940</td><td>null</td><td>null</td><td>catering</td><td>OHUB</td><td>Other</td><td>Unknown</td><td>Unknown</td><td>[Other]</td><td>Kaygeeâ€™s kitchen</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td> /  / 00c57c31-a3fd-4aff-9251-40d7ef12dc1f</td><td>null</td><td>null</td><td>00c57c31-a3fd-4aff-9251-40d7ef12dc1f</td><td>Action in Autism</td><td>Keal Rd</td><td>4001</td><td>Sydenham</td><td>-29.831225</td><td>30.982534</td><td>Education</td><td>null</td><td>null</td><td>null</td><td>Haig Road 105, Durban North</td><td>4051.0</td><td>null</td><td>-29.831225</td><td>30.982534</td><td>['establishment', 'point_of_interest', 'school']</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Action in Autism</td><td>Keal Rd</td><td>4001</td><td>Sydenham</td><td>ZA~CRM_OTHER~ECBA232FC76EAF63F2EEFBDE8130EB2B</td><td>Education</td><td>OHUB</td><td>Student / School dormitory</td><td>Unknown</td><td>Unknown</td><td>[Other, Student / School dormitory]</td><td>Action in Autism,Keal Rd,Sydenham</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td> /  / 015c9f3e-510b-3fad-a3b4-7544ca705531</td><td>null</td><td>null</td><td>015c9f3e-510b-3fad-a3b4-7544ca705531</td><td>BLUE STRAWBERRY CATERERS</td><td>SPRINGFIELD INDUSTRIAL PARK</td><td>4016</td><td>null</td><td>-29.804981</td><td>31.00548999999999</td><td>Conferencing</td><td>null</td><td>+27 31 579 1463</td><td>null</td><td>Ebonyfield Avenue 48, Durban</td><td>4051</td><td>null</td><td>-29.804981</td><td>31.00548999999999</td><td>['establishment', 'food', 'point_of_interest']</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>BLUE STRAWBERRY CATERERS</td><td>SPRINGFIELD INDUSTRIAL PARK</td><td>4016</td><td>null</td><td>ZA~ARMSTRONG~OPDA4606SA</td><td>Conferencing</td><td>OHUB</td><td>Other</td><td>Unknown</td><td>aw</td><td>[Other]</td><td>BLUE STRAWBERRY CATERERS,SPRINGFIELD INDUSTRIAL PARK</td><td>1</td><td>6001087305815</td><td>Sales Data</td><td>robertsons medium rajah</td></tr><tr><td> /  / 015c9f3e-510b-3fad-a3b4-7544ca705531</td><td>null</td><td>null ...

# %%
print(universeRelevantProducts.where(f.col('rationale').isNotNull()).select('operatorId').distinct().count(),'\n'
      ,universeRelevantProducts.select('operatorId').distinct().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">9856
#  65298
# </div>

# %%
universeRelevantProducts.write.mode('overwrite').saveAsTable('data_user_hien.valueTier_opr_cuEanCode_' + countryCode)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(spark.table('data_user_hien.valueTier_opr_cuEanCode_' + countryCode) )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>operatorId</th><th>osmId</th><th>placeIdGoogle</th><th>operatorOhubID</th><th>name</th><th>address</th><th>postalCode</th><th>city</th><th>latitude</th><th>longitude</th><th>businessType</th><th>website</th><th>phone</th><th>nameGoogle</th><th>addressGoogle</th><th>postalCodeGoogle</th><th>cityGoogle16</th><th>latitudeGoogle</th><th>longitudeGoogle</th><th>businessTypeGoogle</th><th>websiteGoogle</th><th>type</th><th>uid</th><th>user_sid</th><th>nameOSM</th><th>addressOSM</th><th>postalCodeOSM</th><th>cityOSM</th><th>latitudeOSM</th><th>longitudeOSM</th><th>businessTypeOSM</th><th>websiteOSM</th><th>cuisineTypeOSM</th><th>phoneOSM</th><th>nameOHUB</th><th>addressOhub</th><th>zipcodeOHUB</th><th>cityOHUB</th><th>operatorConcatID</th><th>channelOHUB</th><th>source</th><th>globalChannel</th><th>cuisineType</th><th>chain</th><th>globalListChannels</th><th>addressCombined</th><th>d_buyer</th><th>cuEanCode</th><th>rationale</th><th>productName</th></tr></thead><tbody><tr><td> /  / 00010dae-4243-411d-9139-c99134126c43</td><td>null</td><td>null</td><td>00010dae-4243-411d-9139-c99134126c43</td><td>Aliwal Dive Centre</td><td>null</td><td>null</td><td>null</td><td>-30.207022</td><td>30.800041999999998</td><td>Conferencing</td><td>null</td><td>null</td><td>null</td><td>Moodie Street 2, Umkomaas</td><td>4170.0</td><td>null</td><td>-30.207022</td><td>30.800041999999998</td><td>['establishment', 'lodging', 'point_of_interest', 'travel_agency']</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Aliwal Dive Centre</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Conferencing</td><td>OHUB</td><td>Other</td><td>Unknown</td><td>Unknown</td><td>[Other]</td><td>Aliwal Dive Centre</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td> /  / 01b398c5-52d8-3b3f-9ba1-9c2c41b5083a</td><td>null</td><td>null</td><td>01b398c5-52d8-3b3f-9ba1-9c2c41b5083a</td><td>Adelante Lodge B&B</td><td>null</td><td>null</td><td>Gauteng</td><td>-29.107016</td><td>26.1974069</td><td>Hotel</td><td>null</td><td>+27 51 444 6400</td><td>null</td><td>Wannenburg Street 4, Bloemfontein</td><td>9301.0</td><td>null</td><td>-29.107016</td><td>26.1974069</td><td>['establishment', 'lodging', 'point_of_interest']</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Adelante Lodge B&B</td><td>null</td><td>null</td><td>Gauteng</td><td>null</td><td>Hotel</td><td>OHUB</td><td>Hotel</td><td>Unknown</td><td>Unknown</td><td>[Other, Hotel, Motel]</td><td>Adelante Lodge B&B,Gauteng</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td> /  / 02c42df1-5090-3f6e-a16a-fba46f0c8d4c</td><td>null</td><td>null</td><td>02c42df1-5090-3f6e-a16a-fba46f0c8d4c</td><td>Fairways Drakensberg</td><td>Khotso Lodge & Horse Trails  Drakensberg Gardens Road  Underberg  3257  South Africa</td><td>3257</td><td>null</td><td>-29.7459628</td><td>29.4264076</td><td>Hotel</td><td>null</td><td>+27 82 495 1345</td><td>null</td><td> </td><td>3257.0</td><td>null</td><td>-29.7459628</td><td>29.4264076</td><td>['campground', 'establishment', 'lodging', 'park', 'point_of_interest', 'travel_agency']</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Fairways Drakensberg</td><td>Khotso Lodge & Horse Trails  Drakensberg Gardens Road  Underberg  3257  South Africa</td><td>3257</td><td>null</td><td>null</td><td>Hotel</td><td>OHUB</td><td>Other</td><td>Unknown</td><td>Unknown</td><td>[Other]</td><td>Fairways Drakensberg,Khotso Lodge & Horse Trails  Drakensberg Gardens Road  Unde ...

# %%
data_user_hien.valueTier_opr_cuEanCode_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3867952979264562&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>data_user_hien<span class="ansi-blue-fg">.</span>valueTier_opr_cuEanCode_
#
# <span class="ansi-red-fg">NameError</span>: name &#39;data_user_hien&#39; is not defined</div>

# %%
from datetime import date
today = date.today().strftime("%Y%m%d")

for countryCode in [("pl")]:
  dbutils.notebook.run("/Shared/dataCleaning/Global/propensity_to_buy/propensityModelScaleAI", 
                       12000, 
                       { 
                        "countryCode": countryCode, 
                        "date": today, 
                        "testSize": 0.5, 
                        "maxIter": 1000})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-410198495289425&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      9</span>                         <span class="ansi-blue-fg">&#34;date&#34;</span><span class="ansi-blue-fg">:</span> today<span class="ansi-blue-fg">,</span>
# ...
